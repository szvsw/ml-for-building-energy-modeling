# %% [markdown]
# # Modularized Training

# %% [markdown]
# ## Imports / Setup

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams["figure.dpi"] = 100
matplotlib.rcParams["savefig.dpi"] = 300
# load style sheet for matplotlib, a plotting library we use for 2D visualizations
plt.style.use(
    "https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-dark.mplstyle"
)
plt.style.use("dark_background")
plt.rcParams.update(
    {
        "figure.facecolor": (0.22, 0.22, 0.22, 1.0),
        "axes.facecolor": (0.22, 0.22, 0.22, 1.0),
        "savefig.facecolor": (0.22, 0.22, 0.22, 1.0),
        "grid.color": (0.4, 0.4, 0.4, 1.0),
    }
)
plt.set_cmap("plasma")

# %% [markdown]
# ## Lib Imports

# %%
from surrogate import Surrogate
from schema import Schema
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# ERROR:Schema:Failed to import a package! Be wary about continuing...
# Traceback (most recent call last):
#   File "c:\Users\Sam Wolk\Dropbox\mit\2023_spring\ml\ml-for-building-energy-modeling\ml-for-bem\schema.py", line 25, in <module>
#     from pyumi.shoeboxer.shoebox import ShoeBox
# ModuleNotFoundError: No module named 'pyumi'
# INFO:Surrogate:Using cuda for surrogate model.

# %% [markdown]
# ## Init

# %%
schema = Schema()
surrogate = Surrogate(schema=schema)
# Out:
# INFO:Surrogate:Loading the full dataset into main RAM...
# INFO:Surrogate:Finished loading the full dataset.
# INFO:Surrogate:Full Input Batch Size (in storage form, not MLVec Form): 382.750176MB
# INFO:Surrogate:Loading climate data...
# INFO:Surrogate:Finished loading climate data.
# INFO:Surrogate:Checking model dimensions...
# INFO:Surrogate:28 building parameters per input vector
# INFO:Surrogate:11 timeseries per input vector
# INFO:Surrogate:4 timeseries per output vector
# INFO:Surrogate:12 timesteps in output.
# INFO:Surrogate:Initializing machine learning objects...
# INFO:Surrogate:ML objects initialized.

# %% [markdown]
# ## Data Inspection

# %%
surrogate.plot_params(start_ix=0, count=10000, include_whiskers=True, title="Parameter Overview")
# Out:
# INFO:Surrogate:Constructing building vector for batch...
# INFO:Surrogate:Building vector for batch constructed.

# %%
surrogate.plot_true_results(start_ix=0,count=1000, ylim=0.5)

# %%
surrogate.plot_weather_vector(bldg_ix=237234, param="dbt")
# Out:
# INFO:Surrogate:Constructing climate timeseries for batch...
# INFO:Surrogate:Climate timeseries for batch constructed.

# %% [markdown]
# ## Training

# %%
surrogate.train(
    run_name="separate_zone_norm_with_annual_norm",
    dataloader_batch_size=100, 
    mini_epoch_batch_size=25000,
    n_full_epochs=5,
    lr_schedule=[1e-3,1e-3,1e-3,5e-4,1e-4]
)
# Out:
# INFO:Surrogate:Constructing dataset...
# INFO:Surrogate:Constructing building vector for batch...
# INFO:Surrogate:Building vector for batch constructed.
# INFO:Surrogate:Constructing climate timeseries for batch...
# INFO:Surrogate:Climate timeseries for batch constructed.
# INFO:Surrogate:Constructing schedules for batch...
# INFO:Surrogate:Schedules for batch constructed.
# INFO:Surrogate:Dataset constructed.
# INFO:Surrogate:Building dataloaders...
# INFO:Surrogate:Dataloaders built.
# INFO:Surrogate:dict_keys(['params', 'lr', 'betas', 'eps', 'weight_decay', 'amsgrad', 'maximize', 'foreach', 'capturable', 'differentiable', 'fused'])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 surrogate.train(
#       2     run_name="separate_zone_norm_with_annual_norm",
#       3     dataloader_batch_size=100,
#       4     mini_epoch_batch_size=25000,
# ...
